# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('adult.csv')
df.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
col = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','target']

# %%
df.columns=col
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# target            0
# dtype: int64

# %% [markdown]
# **Creating Subsets**

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
s1 = df[df['sex']==' Male']
s1
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 8       42            Private  159449      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32556   40            Private  154374        HS-grad              9
# 32558   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
s2 = df[df['sex']==' Female']
s2
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 3       28        Private  338409      Bachelors             13
# 4       37        Private  284582        Masters             14
# 5       49        Private  160187            9th              5
# 7       31        Private   45781        Masters             14
# 11      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32545   37        Private  198216     Assoc-acdm             12
# 32548   43      State-gov  255835   Some-college             10
# 32555   27        Private  257302     Assoc-acdm             12
# 32557   58        Private  151910        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#                marital-status        occupation     relationship    race  \
# 3          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
s3=df[df['race']==' White']
s3
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 4       37            Private  284582      Masters             14
# 6       52   Self-emp-not-inc  209642      HS-grad              9
# 7       31            Private   45781      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
s4=df[df['race']==' Black']
s4
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 2       53   Private  234721           11th              7
# 3       28   Private  338409      Bachelors             13
# 5       49   Private  160187            9th              5
# 9       37   Private  280464   Some-college             10
# 12      32   Private  205019     Assoc-acdm             12
# ...    ...       ...     ...            ...            ...
# 32520   33   Private  273243        HS-grad              9
# 32534   22   Private  325033           12th              8
# 32536   30   Private  345898        HS-grad              9
# 32537   38   Private  139180      Bachelors             13
# 32540   41         ?  202822        HS-grad              9
#
#                marital-status          occupation    relationship    race  \
# 2          Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3          Married-civ-spouse      Prof-specialty            Wife   Black
# ...

# %%
s5=df[df['race']== ' Asian-Pac-Islander']
s5
# Out:
#        age   workclass  fnlwgt      education  education-num  \
# 10      30   State-gov  141297      Bachelors             13
# 13      40     Private  121772      Assoc-voc             11
# 26      54           ?  180211   Some-college             10
# 92      30     Private  117747        HS-grad              9
# 138     49     Private   81973   Some-college             10
# ...    ...         ...     ...            ...            ...
# 32456   33     Private  139057        Masters             14
# 32485   24     Private  216984   Some-college             10
# 32530   30           ?   33811      Bachelors             13
# 32532   54     Private  337992      Bachelors             13
# 32552   32     Private  116138        Masters             14
#
#             marital-status        occupation    relationship  \
# 10      Married-civ-spouse    Prof-specialty         Husband
# 13      Married-civ-spouse      Craft-repair         Husband
# ...

# %%
s6=df[df['race']== ' Amer-Indian-Eskimo']
s6
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 14      34   Private  245487        7th-8th              4
# 211     35   Private  153790   Some-college             10
# 225     60         ?   24215           10th              6
# 446     51   Private   56915        HS-grad              9
# 515     25   Private  267044   Some-college             10
# ...    ...       ...     ...            ...            ...
# 32230   44   Private   33105        HS-grad              9
# 32241   33   Private  356015        HS-grad              9
# 32248   35   Private   91839      Bachelors             13
# 32424   23   Private  180771        1st-4th              2
# 32550   32   Private   34066           10th              6
#
#             marital-status          occupation    relationship  \
# 14      Married-civ-spouse    Transport-moving         Husband
# 211          Never-married               Sales   Not-in-family
# 225               Divorced                   ?   Not-in-family
# ...

# %%
s7=df[df['race']== ' Other']
s7
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 49      25   Private   32275   Some-college             10
# 232     33   Private  110978   Some-college             10
# 355     65   Private  161400           11th              7
# 403     28   Private  166481        7th-8th              4
# 529     44   Private  109339           11th              7
# ...    ...       ...     ...            ...            ...
# 32074   27         ?  147638        Masters             14
# 32231   30   Private  215441   Some-college             10
# 32262   27   Private  176761        HS-grad              9
# 32431   36   Private  208068      Preschool              1
# 32543   31   Private  199655        Masters             14
#
#             marital-status          occupation     relationship    race  \
# 49      Married-civ-spouse     Exec-managerial             Wife   Other
# 232               Divorced        Craft-repair   Other-relative   Other
# ...

# %% [markdown]
# **Merging**

# %%
m1 = pd.concat([s1,s5])
m1
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 8       42            Private  159449      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32456   33            Private  139057        Masters             14
# 32485   24            Private  216984   Some-college             10
# 32530   30                  ?   33811      Bachelors             13
# 32532   54            Private  337992      Bachelors             13
# 32552   32            Private  116138        Masters             14
#
#             marital-status          occupation    relationship  \
# 0       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
m2 = pd.concat([s2,s6])
m2
# Out:
#        age workclass  fnlwgt   education  education-num  \
# 3       28   Private  338409   Bachelors             13
# 4       37   Private  284582     Masters             14
# 5       49   Private  160187         9th              5
# 7       31   Private   45781     Masters             14
# 11      23   Private  122272   Bachelors             13
# ...    ...       ...     ...         ...            ...
# 32230   44   Private   33105     HS-grad              9
# 32241   33   Private  356015     HS-grad              9
# 32248   35   Private   91839   Bachelors             13
# 32424   23   Private  180771     1st-4th              2
# 32550   32   Private   34066        10th              6
#
#                marital-status          occupation    relationship  \
# 3          Married-civ-spouse      Prof-specialty            Wife
# 4          Married-civ-spouse     Exec-managerial            Wife
# 5       Married-spouse-absent       Other-service   Not-in-family
# ...

# %% [markdown]
# **Sort**

# %%
df_sort = df.sort_values('age')
df_sort
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 15541   17                  ?  112942           10th              6
# 26089   17   Self-emp-not-inc  174120           12th              8
# 22495   17            Private  118792           11th              7
# 22856   17          Local-gov  340043           12th              8
# 12980   17                  ?  262196           10th              6
# ...    ...                ...     ...            ...            ...
# 11511   90            Private   87285        HS-grad              9
# 12450   90                  ?  225063   Some-college             10
# 6623    90            Private  313986           11th              7
# 18831   90            Private  115306        Masters             14
# 8805    90            Private   87372    Prof-school             15
#
#             marital-status          occupation relationship  \
# 15541        Never-married                   ?    Own-child
# ...

# %% [markdown]
# **Transpose**

# %%
df_transpose = df.transpose()

# %%
df_transpose
# Out:
#                               0                   1                    2      \
# age                              50                  38                   53
# workclass          Self-emp-not-inc             Private              Private
# fnlwgt                        83311              215646               234721
# education                 Bachelors             HS-grad                 11th
# education-num                    13                   9                    7
# marital-status   Married-civ-spouse            Divorced   Married-civ-spouse
# occupation          Exec-managerial   Handlers-cleaners    Handlers-cleaners
# relationship                Husband       Not-in-family              Husband
# race                          White               White                Black
# sex                            Male                Male                 Male
# capital-gain                      0                   0                    0
# ...

# %% [markdown]
# **Melt**

# %%
df_melt = pd.melt(df,id_vars=['workclass','education'],var_name='Metric',value_name='value')
df_melt
# Out:
#                 workclass    education  Metric   value
# 0        Self-emp-not-inc    Bachelors     age      50
# 1                 Private      HS-grad     age      38
# 2                 Private         11th     age      53
# 3                 Private    Bachelors     age      28
# 4                 Private      Masters     age      37
# ...                   ...          ...     ...     ...
# 423275            Private   Assoc-acdm  target   <=50K
# 423276            Private      HS-grad  target    >50K
# 423277            Private      HS-grad  target   <=50K
# 423278            Private      HS-grad  target   <=50K
# 423279       Self-emp-inc      HS-grad  target    >50K
#
# [423280 rows x 4 columns]

# %% [markdown]
# **Casting**

# %%
df_cast = pd.pivot_table(df,index=['workclass','occupation'],values=['hours-per-week'])
df_cast
# Out:
#                                  hours-per-week
# workclass    occupation
#  ?            ?                       31.919390
#  Federal-gov  Adm-clerical            40.154574
#               Armed-Forces            40.666667
#               Craft-repair            40.781250
#               Exec-managerial         42.572222
# ...                                         ...
#  Without-pay  Farming-fishing         36.666667
#               Handlers-cleaners       40.000000
#               Machine-op-inspct       25.000000
#               Other-service           55.000000
#               Transport-moving        20.000000
#
# [83 rows x 1 columns]
